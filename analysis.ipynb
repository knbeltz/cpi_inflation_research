# %%
from modules import full_analysis

# %%
full_analysis(2012)
# Out:
# None
#                     Feature       VIF
# 0                    Social  2.617019
# 1             2012 debt_gdp  2.999395
# 2  2012 unemployment rate %  2.752485
# 3                  CPI 2012  3.721866
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2012 inflation rate %   R-squared:                       0.131
# Model:                               OLS   Adj. R-squared:                  0.104
# Method:                    Least Squares   F-statistic:                     4.964
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           0.000927
# Time:                           12:47:06   Log-Likelihood:                -443.77
# No. Observations:                    137   AIC:                             897.5
# Df Residuals:                        132   BIC:                             912.1
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2013)
# Out:
# None
#                     Feature       VIF
# 0                    Social  2.473202
# 1             2013 debt_gdp  2.886304
# 2  2013 unemployment rate %  2.777938
# 3                  CPI 2013  3.461724
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2013 inflation rate %   R-squared:                       0.163
# Model:                               OLS   Adj. R-squared:                  0.137
# Method:                    Least Squares   F-statistic:                     6.413
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           9.53e-05
# Time:                           12:47:06   Log-Likelihood:                -394.83
# No. Observations:                    137   AIC:                             799.7
# Df Residuals:                        132   BIC:                             814.3
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2014)
# Out:
# None
#                     Feature       VIF
# 0                    Social  2.544399
# 1             2014 debt_gdp  3.131244
# 2  2014 unemployment rate %  2.778488
# 3                  CPI 2014  3.555229
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2014 inflation rate %   R-squared:                       0.145
# Model:                               OLS   Adj. R-squared:                  0.119
# Method:                    Least Squares   F-statistic:                     5.507
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           0.000397
# Time:                           12:47:06   Log-Likelihood:                -397.71
# No. Observations:                    135   AIC:                             805.4
# Df Residuals:                        130   BIC:                             819.9
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2015)
# Out:
# None
#                     Feature       VIF
# 0                    Social  2.603934
# 1             2015 debt_gdp  3.132070
# 2  2015 unemployment rate %  2.781875
# 3                  CPI 2015  3.218466
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2015 inflation rate %   R-squared:                       0.161
# Model:                               OLS   Adj. R-squared:                  0.135
# Method:                    Least Squares   F-statistic:                     6.174
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           0.000141
# Time:                           12:47:07   Log-Likelihood:                -417.55
# No. Observations:                    134   AIC:                             845.1
# Df Residuals:                        129   BIC:                             859.6
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2016)
# Out:
# None
#                     Feature       VIF
# 0                    Social  2.862923
# 1             2016 debt_gdp  3.285176
# 2  2016 unemployment rate %  2.817773
# 3                  CPI 2016  3.323916
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2016 inflation rate %   R-squared:                       0.075
# Model:                               OLS   Adj. R-squared:                  0.047
# Method:                    Least Squares   F-statistic:                     2.701
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):             0.0333
# Time:                           12:47:07   Log-Likelihood:                -455.77
# No. Observations:                    138   AIC:                             921.5
# Df Residuals:                        133   BIC:                             936.2
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2017)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.059250
# 1             2017 debt_gdp  3.198125
# 2  2017 unemployment rate %  2.826948
# 3                  CPI 2017  3.213032
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2017 inflation rate %   R-squared:                       0.114
# Model:                               OLS   Adj. R-squared:                  0.087
# Method:                    Least Squares   F-statistic:                     4.325
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):            0.00253
# Time:                           12:47:07   Log-Likelihood:                -433.38
# No. Observations:                    140   AIC:                             876.8
# Df Residuals:                        135   BIC:                             891.5
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2018)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.085459
# 1             2018 debt_gdp  3.197200
# 2  2018 unemployment rate %  2.761443
# 3                  CPI 2018  3.052484
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2018 inflation rate %   R-squared:                       0.090
# Model:                               OLS   Adj. R-squared:                  0.063
# Method:                    Least Squares   F-statistic:                     3.342
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):             0.0121
# Time:                           12:47:08   Log-Likelihood:                -464.14
# No. Observations:                    140   AIC:                             938.3
# Df Residuals:                        135   BIC:                             953.0
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2019)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.136327
# 1             2019 debt_gdp  3.234699
# 2  2019 unemployment rate %  2.598201
# 3                  CPI 2019  3.040806
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2019 inflation rate %   R-squared:                       0.110
# Model:                               OLS   Adj. R-squared:                  0.083
# Method:                    Least Squares   F-statistic:                     4.160
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):            0.00329
# Time:                           12:47:08   Log-Likelihood:                -464.91
# No. Observations:                    140   AIC:                             939.8
# Df Residuals:                        135   BIC:                             954.5
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2020)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.005260
# 1             2020 debt_gdp  3.661780
# 2  2020 unemployment rate %  2.982739
# 3                  CPI 2020  3.415954
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2020 inflation rate %   R-squared:                       0.289
# Model:                               OLS   Adj. R-squared:                  0.267
# Method:                    Least Squares   F-statistic:                     13.48
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           2.97e-09
# Time:                           12:47:09   Log-Likelihood:                -557.77
# No. Observations:                    138   AIC:                             1126.
# Df Residuals:                        133   BIC:                             1140.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2021)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.340633
# 1             2021 debt_gdp  3.595979
# 2  2021 unemployment rate %  2.703338
# 3                  CPI 2021  3.502634
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2021 inflation rate %   R-squared:                       0.273
# Model:                               OLS   Adj. R-squared:                  0.252
# Method:                    Least Squares   F-statistic:                     12.69
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           8.59e-09
# Time:                           13:10:56   Log-Likelihood:                -568.88
# No. Observations:                    140   AIC:                             1148.
# Df Residuals:                        135   BIC:                             1162.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2022)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.435804
# 1             2022 debt_gdp  3.864245
# 2  2022 unemployment rate %  2.644483
# 3                  CPI 2022  3.470626
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2022 inflation rate %   R-squared:                       0.240
# Model:                               OLS   Adj. R-squared:                  0.217
# Method:                    Least Squares   F-statistic:                     10.56
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           1.80e-07
# Time:                           13:11:12   Log-Likelihood:                -624.53
# No. Observations:                    139   AIC:                             1259.
# Df Residuals:                        134   BIC:                             1274.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...

# %%
full_analysis(2023)
# Out:
# None
#                     Feature       VIF
# 0                    Social  3.222067
# 1             2023 debt_gdp  4.058573
# 2  2023 unemployment rate %  2.517167
# 3                  CPI 2023  3.789224
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2023 inflation rate %   R-squared:                       0.187
# Model:                               OLS   Adj. R-squared:                  0.162
# Method:                    Least Squares   F-statistic:                     7.460
# Date:                   Tue, 08 Apr 2025   Prob (F-statistic):           1.93e-05
# Time:                           12:47:10   Log-Likelihood:                -600.09
# No. Observations:                    135   AIC:                             1210.
# Df Residuals:                        130   BIC:                             1225.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
