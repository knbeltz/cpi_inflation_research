# %%
from cpi_module_no_debt_gdp import full_analysis

# %%
full_analysis(2012)
# Out:
# None
# PearsonRResult(statistic=-0.314143047206595, pvalue=0.00012587324385195857)
#                        Feature       VIF
# 0                     CPI 2012  4.712818
# 1  Broad money (% of GDP) 2012  3.663785
# 2   GDP growth (annual %) 2012  1.209243
# 3     2012 unemployment rate %  2.239532
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2012 inflation rate %   R-squared:                       0.105
# Model:                               OLS   Adj. R-squared:                  0.067
# Method:                    Least Squares   F-statistic:                     2.756
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0324
# Time:                           14:32:26   Log-Likelihood:                -329.46
# No. Observations:                     99   AIC:                             668.9
# Df Residuals:                         94   BIC:                             681.9
# Df Model:                              4
# ...

# %%
full_analysis(2013)
# Out:
# None
# PearsonRResult(statistic=-0.3472647205356745, pvalue=1.8741600729218366e-05)
#                        Feature       VIF
# 0                     CPI 2013  4.907784
# 1  Broad money (% of GDP) 2013  3.655736
# 2   GDP growth (annual %) 2013  1.311698
# 3     2013 unemployment rate %  2.126586
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2013 inflation rate %   R-squared:                       0.111
# Model:                               OLS   Adj. R-squared:                  0.074
# Method:                    Least Squares   F-statistic:                     3.000
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0222
# Time:                           14:32:26   Log-Likelihood:                -292.23
# No. Observations:                    101   AIC:                             594.5
# Df Residuals:                         96   BIC:                             607.5
# Df Model:                              4
# ...

# %%
full_analysis(2014)
# Out:
# None
# PearsonRResult(statistic=-0.3365784966203716, pvalue=3.954152644309043e-05)
#                        Feature       VIF
# 0                     CPI 2014  5.652082
# 1  Broad money (% of GDP) 2014  3.869915
# 2   GDP growth (annual %) 2014  1.679928
# 3     2014 unemployment rate %  2.030156
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2014 inflation rate %   R-squared:                       0.085
# Model:                               OLS   Adj. R-squared:                  0.046
# Method:                    Least Squares   F-statistic:                     2.198
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0750
# Time:                           14:32:27   Log-Likelihood:                -300.12
# No. Observations:                    100   AIC:                             610.2
# Df Residuals:                         95   BIC:                             623.3
# Df Model:                              4
# ...

# %%
full_analysis(2015)
# Out:
# None
# PearsonRResult(statistic=-0.33348811199504014, pvalue=5.663961591084637e-05)
#                        Feature       VIF
# 0                     CPI 2015  4.670974
# 1  Broad money (% of GDP) 2015  3.820745
# 2   GDP growth (annual %) 2015  1.491863
# 3     2015 unemployment rate %  2.039104
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2015 inflation rate %   R-squared:                       0.255
# Model:                               OLS   Adj. R-squared:                  0.223
# Method:                    Least Squares   F-statistic:                     8.110
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           1.14e-05
# Time:                           14:32:27   Log-Likelihood:                -303.64
# No. Observations:                    100   AIC:                             617.3
# Df Residuals:                         95   BIC:                             630.3
# Df Model:                              4
# ...

# %%
full_analysis(2016)
# Out:
# None
# PearsonRResult(statistic=-0.28750008733795435, pvalue=0.00045434423994702327)
#                        Feature       VIF
# 0                     CPI 2016  5.067797
# 1  Broad money (% of GDP) 2016  3.721992
# 2   GDP growth (annual %) 2016  1.758176
# 3     2016 unemployment rate %  2.085279
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2016 inflation rate %   R-squared:                       0.190
# Model:                               OLS   Adj. R-squared:                  0.157
# Method:                    Least Squares   F-statistic:                     5.739
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           0.000342
# Time:                           14:32:27   Log-Likelihood:                -311.82
# No. Observations:                    103   AIC:                             633.6
# Df Residuals:                         98   BIC:                             646.8
# Df Model:                              4
# ...

# %%
full_analysis(2017)
# Out:
# None
# PearsonRResult(statistic=-0.34382746640646256, pvalue=1.6483886289572882e-05)
#                        Feature       VIF
# 0                     CPI 2017  4.230208
# 1  Broad money (% of GDP) 2017  3.790743
# 2   GDP growth (annual %) 2017  1.641174
# 3     2017 unemployment rate %  2.194939
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2017 inflation rate %   R-squared:                       0.180
# Model:                               OLS   Adj. R-squared:                  0.147
# Method:                    Least Squares   F-statistic:                     5.497
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           0.000484
# Time:                           14:32:27   Log-Likelihood:                -325.47
# No. Observations:                    105   AIC:                             660.9
# Df Residuals:                        100   BIC:                             674.2
# Df Model:                              4
# ...

# %%
full_analysis(2018)
# Out:
# None
# PearsonRResult(statistic=-0.2694107161769081, pvalue=0.00085651755908435)
#                        Feature       VIF
# 0                     CPI 2018  5.875189
# 1  Broad money (% of GDP) 2018  4.799635
# 2   GDP growth (annual %) 2018  2.108806
# 3     2018 unemployment rate %  2.054294
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2018 inflation rate %   R-squared:                       0.165
# Model:                               OLS   Adj. R-squared:                  0.131
# Method:                    Least Squares   F-statistic:                     4.805
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):            0.00141
# Time:                           14:32:28   Log-Likelihood:                -340.76
# No. Observations:                    102   AIC:                             691.5
# Df Residuals:                         97   BIC:                             704.7
# Df Model:                              4
# ...

# %%
full_analysis(2019)
# Out:
# None
# PearsonRResult(statistic=-0.23763571925887605, pvalue=0.0035205148186979664)
#                        Feature       VIF
# 0                     CPI 2019  6.355547
# 1  Broad money (% of GDP) 2019  4.853991
# 2   GDP growth (annual %) 2019  1.583039
# 3     2019 unemployment rate %  2.012665
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2019 inflation rate %   R-squared:                       0.129
# Model:                               OLS   Adj. R-squared:                  0.093
# Method:                    Least Squares   F-statistic:                     3.531
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):            0.00989
# Time:                           14:32:28   Log-Likelihood:                -339.80
# No. Observations:                    100   AIC:                             689.6
# Df Residuals:                         95   BIC:                             702.6
# Df Model:                              4
# ...

# %%
full_analysis(2020)
# Out:
# None
# PearsonRResult(statistic=-0.25611311115718116, pvalue=0.0016785164846169305)
#                        Feature       VIF
# 0                     CPI 2020  4.892465
# 1  Broad money (% of GDP) 2020  4.943112
# 2   GDP growth (annual %) 2020  1.663196
# 3     2020 unemployment rate %  2.441553
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2020 inflation rate %   R-squared:                       0.068
# Model:                               OLS   Adj. R-squared:                  0.027
# Method:                    Least Squares   F-statistic:                     1.666
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):              0.165
# Time:                           14:32:28   Log-Likelihood:                -409.48
# No. Observations:                     97   AIC:                             829.0
# Df Residuals:                         92   BIC:                             841.8
# Df Model:                              4
# ...

# %%
full_analysis(2021)
# Out:
# None
# PearsonRResult(statistic=-0.20574975086008812, pvalue=0.012116546498551107)
#                        Feature       VIF
# 0                     CPI 2021  5.796430
# 1  Broad money (% of GDP) 2021  4.479894
# 2   GDP growth (annual %) 2021  2.140504
# 3     2021 unemployment rate %  2.346454
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2021 inflation rate %   R-squared:                       0.083
# Model:                               OLS   Adj. R-squared:                  0.042
# Method:                    Least Squares   F-statistic:                     2.021
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0982
# Time:                           14:32:28   Log-Likelihood:                -357.63
# No. Observations:                     94   AIC:                             725.3
# Df Residuals:                         89   BIC:                             738.0
# Df Model:                              4
# ...

# %%
full_analysis(2022)
# Out:
# None
# PearsonRResult(statistic=-0.19446337739392835, pvalue=0.01747919097574442)
#                        Feature       VIF
# 0                     CPI 2022  5.354160
# 1  Broad money (% of GDP) 2022  4.093461
# 2   GDP growth (annual %) 2022  1.926369
# 3     2022 unemployment rate %  2.038410
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2022 inflation rate %   R-squared:                       0.053
# Model:                               OLS   Adj. R-squared:                  0.005
# Method:                    Least Squares   F-statistic:                     1.104
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):              0.360
# Time:                           14:32:29   Log-Likelihood:                -375.53
# No. Observations:                     84   AIC:                             761.1
# Df Residuals:                         79   BIC:                             773.2
# Df Model:                              4
# ...

# %%
full_analysis(2023)
# Out:
# None
# PearsonRResult(statistic=-0.18165629719190712, pvalue=0.02766403705283889)
#                        Feature       VIF
# 0                     CPI 2023  4.961311
# 1  Broad money (% of GDP) 2023  3.887225
# 2   GDP growth (annual %) 2023  1.498684
# 3     2023 unemployment rate %  2.060510
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2023 inflation rate %   R-squared:                       0.094
# Model:                               OLS   Adj. R-squared:                  0.040
# Method:                    Least Squares   F-statistic:                     1.746
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):              0.150
# Time:                           14:32:29   Log-Likelihood:                -302.93
# No. Observations:                     72   AIC:                             615.9
# Df Residuals:                         67   BIC:                             627.3
# Df Model:                              4
# ...
