# %%
from cpi_module import full_analysis_cpi

# %%
full_analysis_cpi(2012)
# Out:
# None
# PearsonRResult(statistic=-0.314143047206595, pvalue=0.00012587324385195857)
#                        Feature       VIF
# 0                     CPI 2012  5.696917
# 1  Broad money (% of GDP) 2012  5.470367
# 2   GDP growth (annual %) 2012  1.593845
# 3                2012 debt_gdp  4.224248
# 4     2012 unemployment rate %  2.269830
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2012 inflation rate %   R-squared:                       0.194
# Model:                               OLS   Adj. R-squared:                  0.150
# Method:                    Least Squares   F-statistic:                     4.427
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):            0.00117
# Time:                           14:39:13   Log-Likelihood:                -321.50
# No. Observations:                     98   AIC:                             655.0
# Df Residuals:                         92   BIC:                             670.5
# ...

# %%
full_analysis_cpi(2013)
# Out:
# None
# PearsonRResult(statistic=-0.3472647205356745, pvalue=1.8741600729218366e-05)
#                        Feature       VIF
# 0                     CPI 2013  5.035489
# 1  Broad money (% of GDP) 2013  5.488204
# 2   GDP growth (annual %) 2013  1.376022
# 3                2013 debt_gdp  4.196251
# 4     2013 unemployment rate %  2.298121
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2013 inflation rate %   R-squared:                       0.230
# Model:                               OLS   Adj. R-squared:                  0.189
# Method:                    Least Squares   F-statistic:                     5.622
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           0.000141
# Time:                           14:39:13   Log-Likelihood:                -282.56
# No. Observations:                    100   AIC:                             577.1
# Df Residuals:                         94   BIC:                             592.7
# ...

# %%
full_analysis_cpi(2014)
# Out:
# None
# PearsonRResult(statistic=-0.3365784966203716, pvalue=3.954152644309043e-05)
#                        Feature       VIF
# 0                     CPI 2014  5.827427
# 1  Broad money (% of GDP) 2014  5.565049
# 2   GDP growth (annual %) 2014  2.176046
# 3                2014 debt_gdp  4.337625
# 4     2014 unemployment rate %  2.204428
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2014 inflation rate %   R-squared:                       0.174
# Model:                               OLS   Adj. R-squared:                  0.130
# Method:                    Least Squares   F-statistic:                     3.923
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):            0.00285
# Time:                           14:39:14   Log-Likelihood:                -292.46
# No. Observations:                     99   AIC:                             596.9
# Df Residuals:                         93   BIC:                             612.5
# ...

# %%
full_analysis_cpi(2015)
# Out:
# None
# PearsonRResult(statistic=-0.33348811199504014, pvalue=5.663961591084637e-05)
#                        Feature       VIF
# 0                     CPI 2015  5.161822
# 1  Broad money (% of GDP) 2015  5.296278
# 2   GDP growth (annual %) 2015  1.501673
# 3                2015 debt_gdp  4.505355
# 4     2015 unemployment rate %  2.214015
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2015 inflation rate %   R-squared:                       0.275
# Model:                               OLS   Adj. R-squared:                  0.236
# Method:                    Least Squares   F-statistic:                     7.068
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           1.22e-05
# Time:                           14:39:14   Log-Likelihood:                -299.13
# No. Observations:                     99   AIC:                             610.3
# Df Residuals:                         93   BIC:                             625.8
# ...

# %%
full_analysis_cpi(2016)
# Out:
# None
# PearsonRResult(statistic=-0.28750008733795435, pvalue=0.00045434423994702327)
#                        Feature       VIF
# 0                     CPI 2016  5.481752
# 1  Broad money (% of GDP) 2016  5.167037
# 2   GDP growth (annual %) 2016  1.832881
# 3                2016 debt_gdp  4.464096
# 4     2016 unemployment rate %  2.269646
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2016 inflation rate %   R-squared:                       0.189
# Model:                               OLS   Adj. R-squared:                  0.147
# Method:                    Least Squares   F-statistic:                     4.467
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):            0.00106
# Time:                           14:39:14   Log-Likelihood:                -300.87
# No. Observations:                    102   AIC:                             613.7
# Df Residuals:                         96   BIC:                             629.5
# ...

# %%
full_analysis_cpi(2017)
# Out:
# None
# PearsonRResult(statistic=-0.34382746640646256, pvalue=1.6483886289572882e-05)
#                        Feature       VIF
# 0                     CPI 2017  5.329293
# 1  Broad money (% of GDP) 2017  5.167244
# 2   GDP growth (annual %) 2017  2.013706
# 3                2017 debt_gdp  4.643101
# 4     2017 unemployment rate %  2.272201
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2017 inflation rate %   R-squared:                       0.241
# Model:                               OLS   Adj. R-squared:                  0.203
# Method:                    Least Squares   F-statistic:                     6.231
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           4.65e-05
# Time:                           14:39:14   Log-Likelihood:                -312.12
# No. Observations:                    104   AIC:                             636.2
# Df Residuals:                         98   BIC:                             652.1
# ...

# %%
full_analysis_cpi(2018)
# Out:
# None
# PearsonRResult(statistic=-0.2694107161769081, pvalue=0.00085651755908435)
#                        Feature       VIF
# 0                     CPI 2018  6.730834
# 1  Broad money (% of GDP) 2018  5.925437
# 2   GDP growth (annual %) 2018  2.117428
# 3                2018 debt_gdp  3.788357
# 4     2018 unemployment rate %  2.227850
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2018 inflation rate %   R-squared:                       0.430
# Model:                               OLS   Adj. R-squared:                  0.400
# Method:                    Least Squares   F-statistic:                     14.31
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           1.96e-10
# Time:                           14:39:15   Log-Likelihood:                -317.91
# No. Observations:                    101   AIC:                             647.8
# Df Residuals:                         95   BIC:                             663.5
# ...

# %%
full_analysis_cpi(2019)
# Out:
# None
# PearsonRResult(statistic=-0.23763571925887605, pvalue=0.0035205148186979664)
#                        Feature       VIF
# 0                     CPI 2019  6.737681
# 1  Broad money (% of GDP) 2019  5.997297
# 2   GDP growth (annual %) 2019  1.649524
# 3                2019 debt_gdp  3.822283
# 4     2019 unemployment rate %  2.219803
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2019 inflation rate %   R-squared:                       0.348
# Model:                               OLS   Adj. R-squared:                  0.313
# Method:                    Least Squares   F-statistic:                     9.916
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           1.27e-07
# Time:                           14:39:15   Log-Likelihood:                -322.20
# No. Observations:                     99   AIC:                             656.4
# Df Residuals:                         93   BIC:                             672.0
# ...

# %%
full_analysis_cpi(2020)
# Out:
# None
# PearsonRResult(statistic=-0.25611311115718116, pvalue=0.0016785164846169305)
#                        Feature       VIF
# 0                     CPI 2020  5.974208
# 1  Broad money (% of GDP) 2020  5.811321
# 2   GDP growth (annual %) 2020  1.621454
# 3                2020 debt_gdp  3.671134
# 4     2020 unemployment rate %  2.463146
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2020 inflation rate %   R-squared:                       0.488
# Model:                               OLS   Adj. R-squared:                  0.459
# Method:                    Least Squares   F-statistic:                     17.15
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           6.99e-12
# Time:                           14:39:15   Log-Likelihood:                -376.97
# No. Observations:                     96   AIC:                             765.9
# Df Residuals:                         90   BIC:                             781.3
# ...

# %%
full_analysis_cpi(2021)
# Out:
# None
# PearsonRResult(statistic=-0.20574975086008812, pvalue=0.012116546498551107)
#                        Feature       VIF
# 0                     CPI 2021  6.570734
# 1  Broad money (% of GDP) 2021  6.384383
# 2   GDP growth (annual %) 2021  2.528189
# 3                2021 debt_gdp  6.395963
# 4     2021 unemployment rate %  2.341074
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2021 inflation rate %   R-squared:                       0.127
# Model:                               OLS   Adj. R-squared:                  0.077
# Method:                    Least Squares   F-statistic:                     2.543
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0339
# Time:                           14:39:15   Log-Likelihood:                -351.98
# No. Observations:                     93   AIC:                             716.0
# Df Residuals:                         87   BIC:                             731.2
# ...

# %%
full_analysis_cpi(2022)
# Out:
# None
# PearsonRResult(statistic=-0.19446337739392835, pvalue=0.01747919097574442)
#                        Feature       VIF
# 0                     CPI 2022  5.529766
# 1  Broad money (% of GDP) 2022  5.755903
# 2   GDP growth (annual %) 2022  2.138731
# 3                2022 debt_gdp  5.426676
# 4     2022 unemployment rate %  2.063637
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2022 inflation rate %   R-squared:                       0.155
# Model:                               OLS   Adj. R-squared:                  0.100
# Method:                    Least Squares   F-statistic:                     2.852
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):             0.0204
# Time:                           14:39:16   Log-Likelihood:                -370.77
# No. Observations:                     84   AIC:                             753.5
# Df Residuals:                         78   BIC:                             768.1
# ...

# %%
full_analysis_cpi(2023)
# Out:
# None
# PearsonRResult(statistic=-0.18165629719190712, pvalue=0.02766403705283889)
#                        Feature       VIF
# 0                     CPI 2023  5.312410
# 1  Broad money (% of GDP) 2023  5.157099
# 2   GDP growth (annual %) 2023  1.575020
# 3                2023 debt_gdp  4.606650
# 4     2023 unemployment rate %  2.071090
# None
#                               OLS Regression Results
# ...
# Dep. Variable:     2023 inflation rate %   R-squared:                       0.303
# Model:                               OLS   Adj. R-squared:                  0.250
# Method:                    Least Squares   F-statistic:                     5.738
# Date:                   Sat, 26 Apr 2025   Prob (F-statistic):           0.000187
# Time:                           14:39:16   Log-Likelihood:                -293.51
# No. Observations:                     72   AIC:                             599.0
# Df Residuals:                         66   BIC:                             612.7
# ...
